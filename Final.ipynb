# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from PIL import Image
import pandas as pd
from PIL import ImageEnhance
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
class Result_Automation():
        
    def rslt_download(self,y,z,r):
        self.service = Service(ChromeDriverManager().install())

        if type(r) == tuple:
            a,b = r
        else:
            a=r
            b=r
    
        driver = webdriver.Chrome(service=self.service)

        url = 'https://rtmnuresults.org/Default.aspx'

        print(driver.title)
        try:
            driver.get(url)
            time.sleep(2)
            submit_button = driver.find_element(By.ID, y)
            submit_button.click()
            time.sleep(2)

    
            dropdown_element = driver.find_element(By.ID, 'ddlselectfaculty') 

            dropdown = Select(dropdown_element)

            dropdown.select_by_value('1')
            time.sleep(0.2)

            dropdown_element1 = driver.find_element(By.ID, 'ddlselectexam')

            dropdown1 = Select(dropdown_element1)

            dropdown1.select_by_value(z)
            time.sleep(0.2)
            for i in range(a,b+1):
                x = str(i)
                field1 = driver.find_element(By.ID, 'txtrollno')
                field1.clear()
                field1.send_keys(x)
                time.sleep(0.2)

                submit_button = driver.find_element(By.ID, 'imgbtnviewmarksheet')
                submit_button.click()

                time.sleep(3)
                screenshot_path = f"screenshot {x}.png" 
                driver.save_screenshot(screenshot_path)
                print(f"Screenshot saved at {screenshot_path}")
                driver.back()
                time.sleep(2)

        finally:
            driver.quit()
    def thirdsem_rslt(self,r):
        if type(r) == tuple:
            x,y = r
        else:
            x=r
            y=r
        for i in range(x,y+1):
            image_path = f"screenshot {str(i)}.png" 
            image = Image.open(image_path)
            custom_config = r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789'
            contrast = 2.8
            x1=image.crop((660, 300,700,318)).resize((400,180))
            x2=image.crop((660, 318,700,330)).resize((400,180))
            x3=image.crop((660, 330,700,343)).resize((400,180))
            x4=image.crop((660, 341,700,354)).resize((400,180))
            x5=image.crop((660, 353,700,366)).resize((400,180))
            x6=image.crop((660, 366,700,379)).resize((400,180))
            x7=image.crop((660, 390,700,403)).resize((400,180))
            x8=image.crop((660, 412,700,425)).resize((400,180))
            x9=image.crop((660, 437,700,449)).resize((400,180))
            x10=image.crop((668, 450,688,463)).resize((400,180))
            x11=image.crop((290, 520,350,535)).resize((400,150))
            extracted_text1 = pytesseract.image_to_string(ImageEnhance.Contrast(x1)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text2 = pytesseract.image_to_string(ImageEnhance.Contrast(x2)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text3 = pytesseract.image_to_string(ImageEnhance.Contrast(x3)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text4 = pytesseract.image_to_string(ImageEnhance.Contrast(x4)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text5 = pytesseract.image_to_string(ImageEnhance.Contrast(x5)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text6 = pytesseract.image_to_string(ImageEnhance.Contrast(x6)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text7 = pytesseract.image_to_string(ImageEnhance.Contrast(x7)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text8 = pytesseract.image_to_string(ImageEnhance.Contrast(x8)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text9 = pytesseract.image_to_string(ImageEnhance.Contrast(x9)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text10 = pytesseract.image_to_string(ImageEnhance.Contrast(x10)
            .enhance(10).convert("L"),config = r'--oem 3 --psm 6 -c tessedit_char_whitelist=A+')
            extracted_text11 = pytesseract.image_to_string(ImageEnhance.Contrast(x11)
            .enhance(contrast).convert("L"), config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789.')
            extracted_text = pytesseract.image_to_string(ImageEnhance.Contrast(image.crop((640, 520,750,535)).resize((400,150))).enhance(contrast).convert("L"),config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=PASBYGRCEFIL ') 
            print(f"Extracted Text: {str(i)}")
            print('1',extracted_text1.split('\n')[0][0:2])
            print('2',extracted_text2.split('\n')[0][0:2])
            print('3',extracted_text3.split('\n')[0][0:2])
            print('4',extracted_text4.split('\n')[0][0:2])
            print('5',extracted_text5.split('\n')[0][0:2])
            print('6',extracted_text6.split('\n')[0][0:2])
            print('7',extracted_text7.split('\n')[0][0:2])
            print('8',extracted_text8.split('\n')[0][0:2])
            print('9',extracted_text9.split('\n')[0][0:2])
            print('10',extracted_text10.split('\n')[0][0:2])
            print('cgpa',extracted_text11.split('\n')[0][0:4])
            print('-->',extracted_text[0:-1])

    def fourthsem_rslt(self,r):
        if type(r) == tuple:
            x,y = r
        else:
            x=r
            y=r
        for i in range(x,y+1):
            image_path = f"screenshot {str(i)}.png" 
            image = Image.open(image_path)
            custom_config = r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789'
            contrast = 2.8
            x1=image.crop((660, 300,700,318)).resize((400,180))
            x2=image.crop((660, 318,700,330)).resize((400,180))
            x3=image.crop((660, 330,700,343)).resize((400,180))
            x4=image.crop((660, 353,700,366)).resize((400,180))
            x5=image.crop((660, 366,700,379)).resize((400,180))
            x6=image.crop((660, 390,700,403)).resize((400,180))
            x7=image.crop((660, 400,700,413)).resize((400,180))
            x8=image.crop((660, 425,700,438)).resize((400,180))
            x9=image.crop((660, 438,700,451)).resize((400,180))
            x10=image.crop((660, 462,700,475)).resize((400,180))
            x11=image.crop((290, 520,350,535)).resize((400,150))
            extracted_text1 = pytesseract.image_to_string(ImageEnhance.Contrast(x1)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text2 = pytesseract.image_to_string(ImageEnhance.Contrast(x2)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text3 = pytesseract.image_to_string(ImageEnhance.Contrast(x3)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text4 = pytesseract.image_to_string(ImageEnhance.Contrast(x4)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text5 = pytesseract.image_to_string(ImageEnhance.Contrast(x5)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text6 = pytesseract.image_to_string(ImageEnhance.Contrast(x6)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text7 = pytesseract.image_to_string(ImageEnhance.Contrast(x7)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text8 = pytesseract.image_to_string(ImageEnhance.Contrast(x8)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text9 = pytesseract.image_to_string(ImageEnhance.Contrast(x9)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text10 = pytesseract.image_to_string(ImageEnhance.Contrast(x10)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text11 = pytesseract.image_to_string(ImageEnhance.Contrast(x11)
            .enhance(contrast).convert("L"), config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789.')
            extracted_text = pytesseract.image_to_string(ImageEnhance.Contrast(image.crop((640, 520,750,535)).resize((400,150))).enhance(contrast).convert("L"),config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=PASBYGRCEFIL ') 
            print(f"Extracted Text: {str(i)}")
            print('1',extracted_text1.split('\n')[0][0:2])
            print('2',extracted_text2.split('\n')[0][0:2])
            print('3',extracted_text3.split('\n')[0][0:2])
            print('4',extracted_text4.split('\n')[0][0:2])
            print('5',extracted_text5.split('\n')[0][0:2])
            print('6',extracted_text6.split('\n')[0][0:2])
            print('7',extracted_text7.split('\n')[0][0:2])
            print('8',extracted_text8.split('\n')[0][0:2])
            print('9',extracted_text9.split('\n')[0][0:2])
            print('10',extracted_text10.split('\n')[0][0:2])
            print('cgpa',extracted_text11.split('\n')[0][0:4])
            print('-->',extracted_text[0:-1])
    def thirdsem_table(self,r,save=False):
        if type(r) == tuple:
            x,y = r
        else:
            x=r
            y=r
        df = pd.DataFrame(columns=['Roll No.',"DMGT", "OS", "CAO",'DS','DS lab','DCFM','DCFM lab','PS-1 lab ','UHV','EVS','CGPA','Result'])
        
        for i in range(x,y+1):
            image_path = f"screenshot {str(i)}.png" 
            image = Image.open(image_path)
            custom_config = r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789'
            contrast = 2.8
            x1=image.crop((660, 300,700,318)).resize((400,180))
            x2=image.crop((660, 318,700,330)).resize((400,180))
            x3=image.crop((660, 330,700,343)).resize((400,180))
            x4=image.crop((660, 341,700,354)).resize((400,180))
            x5=image.crop((660, 353,700,366)).resize((400,180))
            x6=image.crop((660, 366,700,379)).resize((400,180))
            x7=image.crop((660, 390,700,403)).resize((400,180))
            x8=image.crop((660, 412,700,425)).resize((400,180))
            x9=image.crop((660, 437,700,449)).resize((400,180))
            x10=image.crop((668, 450,688,463)).resize((400,180))
            x11=image.crop((290, 520,350,535)).resize((400,150))
            extracted_text1 = pytesseract.image_to_string(ImageEnhance.Contrast(x1)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text2 = pytesseract.image_to_string(ImageEnhance.Contrast(x2)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text3 = pytesseract.image_to_string(ImageEnhance.Contrast(x3)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text4 = pytesseract.image_to_string(ImageEnhance.Contrast(x4)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text5 = pytesseract.image_to_string(ImageEnhance.Contrast(x5)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text6 = pytesseract.image_to_string(ImageEnhance.Contrast(x6)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text7 = pytesseract.image_to_string(ImageEnhance.Contrast(x7)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text8 = pytesseract.image_to_string(ImageEnhance.Contrast(x8)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text9 = pytesseract.image_to_string(ImageEnhance.Contrast(x9)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text10 = pytesseract.image_to_string(ImageEnhance.Contrast(x10)
            .enhance(10).convert("L"),config = r'--oem 3 --psm 6 -c tessedit_char_whitelist=A+')
            extracted_text11 = pytesseract.image_to_string(ImageEnhance.Contrast(x11)
            .enhance(contrast).convert("L"), config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789.')
            extracted_text = pytesseract.image_to_string(ImageEnhance.Contrast(image.crop((640, 520,750,535)).resize((400,150))).enhance(contrast).convert("L"),config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=PASBYGRCEFIL ') 
            new_row = [i,extracted_text1.split('\n')[0][0:2],extracted_text2.split('\n')[0][0:2],extracted_text3.split('\n')[0][0:2],extracted_text4.split('\n')[0][0:2],extracted_text5.split('\n')[0][0:2],extracted_text6.split('\n')[0][0:2],extracted_text7.split('\n')[0][0:2],extracted_text8.split('\n')[0][0:2],extracted_text9.split('\n')[0][0:2],extracted_text10.split('\n')[0][0:2],extracted_text11.split('\n')[0][0:4],extracted_text[0:-1]]
            df.loc[len(df)] = new_row
        if save == True:
            df.to_csv(f'{x} to {y}.csv',index=False)
            print(f'{x} to {y}.csv'+' saved successfully')
        else:
            return df
    def fourthsem_table(self,r,save=False):
        if type(r) == tuple:
            x,y = r
        else:
            x=r
            y=r
        df = pd.DataFrame(columns=['Roll No.',"AI", "TOC", "MFDS",'OOPS','OOPS lab','DBMS','DBMS lab','MCES','MCES lab','Internship','CGPA','Result'])
        for i in range(x,y+1):
            image_path = f"screenshot {str(i)}.png" 
            image = Image.open(image_path)
            custom_config = r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789'
            contrast = 2.8
            x1=image.crop((660, 300,700,318)).resize((400,180))
            x2=image.crop((660, 318,700,330)).resize((400,180))
            x3=image.crop((660, 330,700,343)).resize((400,180))
            x4=image.crop((660, 353,700,366)).resize((400,180))
            x5=image.crop((660, 366,700,379)).resize((400,180))
            x6=image.crop((660, 390,700,403)).resize((400,180))
            x7=image.crop((660, 400,700,413)).resize((400,180))
            x8=image.crop((660, 425,700,438)).resize((400,180))
            x9=image.crop((660, 438,700,451)).resize((400,180))
            x10=image.crop((660, 462,700,475)).resize((400,180))
            x11=image.crop((290, 520,350,535)).resize((400,150))
            extracted_text1 = pytesseract.image_to_string(ImageEnhance.Contrast(x1)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text2 = pytesseract.image_to_string(ImageEnhance.Contrast(x2)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text3 = pytesseract.image_to_string(ImageEnhance.Contrast(x3)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text4 = pytesseract.image_to_string(ImageEnhance.Contrast(x4)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text5 = pytesseract.image_to_string(ImageEnhance.Contrast(x5)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text6 = pytesseract.image_to_string(ImageEnhance.Contrast(x6)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text7 = pytesseract.image_to_string(ImageEnhance.Contrast(x7)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text8 = pytesseract.image_to_string(ImageEnhance.Contrast(x8)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text9 = pytesseract.image_to_string(ImageEnhance.Contrast(x9)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text10 = pytesseract.image_to_string(ImageEnhance.Contrast(x10)
            .enhance(contrast).convert("L"), config=custom_config)
            extracted_text11 = pytesseract.image_to_string(ImageEnhance.Contrast(x11)
            .enhance(contrast).convert("L"), config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=0123456789.')
            extracted_text = pytesseract.image_to_string(ImageEnhance.Contrast(image.crop((640, 520,750,535)).resize((400,150))).enhance(contrast).convert("L"),config=r'--oem 3 --psm 6 -c tessedit_char_whitelist=PASBYGRCEFIL ') 
            new_row = [i,extracted_text1.split('\n')[0][0:2],extracted_text2.split('\n')[0][0:2],extracted_text3.split('\n')[0][0:2],extracted_text4.split('\n')[0][0:2],extracted_text5.split('\n')[0][0:2],extracted_text6.split('\n')[0][0:2],extracted_text7.split('\n')[0][0:2],extracted_text8.split('\n')[0][0:2],extracted_text9.split('\n')[0][0:2],extracted_text10.split('\n')[0][0:2],extracted_text11.split('\n')[0][0:4],extracted_text[0:-1]]
            df.loc[len(df)] = new_row
        if save == True:
            df.to_csv(f'{x} to {y}.csv',index=False)
            print(f'{x} to {y}.csv'+' saved successfully')
        else:
            return df

# %%
winter24 ='ImageButton6'
summer24 = 'ImageButton7'
winter23 ='ImageButton5'
z1='10998'
z2 ='11403'
start = 674718
end = 674751

# %%
results = Result_Automation()

# %%
results.rslt_download(summer24,z2,(start,end))
# Out:
# Screenshot saved at screenshot 674718.png
# Screenshot saved at screenshot 674719.png
# Screenshot saved at screenshot 674720.png
# Screenshot saved at screenshot 674721.png
# Screenshot saved at screenshot 674722.png
# Screenshot saved at screenshot 674723.png
# Screenshot saved at screenshot 674724.png
# Screenshot saved at screenshot 674725.png
# Screenshot saved at screenshot 674726.png
# Screenshot saved at screenshot 674727.png
# Screenshot saved at screenshot 674728.png
# Screenshot saved at screenshot 674729.png
# Screenshot saved at screenshot 674730.png
# Screenshot saved at screenshot 674731.png
# Screenshot saved at screenshot 674732.png
# Screenshot saved at screenshot 674733.png
# Screenshot saved at screenshot 674734.png
# Screenshot saved at screenshot 674735.png
# Screenshot saved at screenshot 674736.png
# Screenshot saved at screenshot 674737.png
# Screenshot saved at screenshot 674738.png
# Screenshot saved at screenshot 674739.png
# ...

# %%
results.thirdsem_rslt(277303)
# Out:
# Extracted Text: 277303
# 1 60
# 2 45
# 3 50
# 4 75
# 5 40
# 6 45
# 7 40
# 8 39
# 9 30
# 10 A+
# cgpa 6.00
# --> PASSBYGRACE

# %%
results.fourthsem_rslt((377116,377117))
# Out:
# Extracted Text: 377116
# 1 45
# 2 47
# 3 45
# 4 52
# 5 32
# 6 45
# 7 31
# 8 47
# 9 36
# 10 48
# cgpa 5.38
# --> PASSBYGRACE
# Extracted Text: 377117
# 1 49
# 2 47
# 3 34
# 4 34
# 5 34
# 6 45
# 7 42
# 8 33
# 9 37
# 10 43
# cgpa
# --> FAL

# %%
results.thirdsem_table((277300,277310),save=True)
# Out:
# 277300 to 277310.csv saved successfully

# %%
results.fourthsem_table((start,end))
# Out:
#     Roll No.  AI TOC MFDS OOPS OOPS lab DBMS DBMS lab MCES MCES lab  \
# 0     674718  77  62   47   73       38   76       32   64       35
# 1     674719  83  80   81   85       47   89       47    7       46
# 2     674720  71  59   76   53       44   66       43   55       43
# 3     674721  72  58   72   45       40   72       46   50       46
# 4     674722  75  65   75   54       44   64       47   64       46
# 5     674723  76   3   75   76       45   90       48   68       46
# 6     674724  76       74   65       36    7       34   59       39
# 7     674725  60  48   48   59       34   65       33   61       38
# 8     674726  55  55   44   41       39    1       45   48       43
# 9     674727  66  68   79   56       47   76       47   55       46
# 10    674728  31  42   19   39       32   39       31   26       34
# 11    674729  66  56   53   45       36   65       34   50       40
# 12    674730  60  52   52   45       32   92       45   51       41
# ...

# %%
results.fourthsem_table((377111,377122))
# Out:
#     Roll No.  AI TOC MFDS OOPS OOPS lab DBMS DBMS lab MCES MCES lab  \
# 0     377111  59  55   45   54       47   49       48   59       44
# 1     377112  46  32   49   38       41   45       44   22       39
# 2     377113  46  45   50   37       44   47       41   32       38
# 3     377114  45  47   50   46       32   38       31   26       36
# 4     377115  45  45   55   45       32   45       32   50       42
# 5     377116  45  47   45   52       32   45       31   47       36
# 6     377117  49  47   34   34       34   45       42   33       37
# 7     377118  46  50   47   45       33   46       31   46       39
# 8     377119  55  46   48   27       35   44       38   42       40
# 9     377120  31  26   39   21       34   38       36   37       34
# 10    377121  45  49   38   38       33   44       31    4       38
# 11    377122  38  54   54   44       45   93       46   48       44
#
#    Internship  CGPA       Result
# 0          48  6.50  PASSBYGRACE
# ...
